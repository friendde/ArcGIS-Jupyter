# %% [markdown]
# GOAL:
#
# - Create points using JSON URL from Open Data site
# - Publish the points to ArcGIS Online or ArcGIS Portal

# %% [markdown]
# Inspired by:
#
# - [Bryan McIntosh - Export ArcGIS Server Map Service Layer to Shapefile](http://www.spatialtimes.com/2016/03/extract-map-service-layer-shapefile-using-python/)
# - [Corey Schafer python JSON YouTube video](https://youtu.be/9N6a-VLBa2I)
# - [Corey Schafer GitHub](https://github.com/CoreyMSchafer/code_snippets/blob/master/Python-JSON/api.py)

# %%
import urllib3
import json
import arcpy
import pandas as pd
import numpy as np

# %% [markdown]
# [urllib3 SSL Warnings](https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings)

# %%
urllib3.disable_warnings()

# %%
# for active city business permits
jsonURL = "https://data.cityofgainesville.org/resource/c2ek-5hm9.json"
#for landlord permits
#jsonURL = "https://data.cityofgainesville.org/resource/c2ek-5hm9.json"
#jsonURL = 'https://data.cityofgainesville.org/api/views/f4t5-t3b5/rows.json'
#geojsonURL = 'https://data.cityofgainesville.org/resource/pqg3-m2ek.geojson'
gdb = r"C:\Users\friendde\Documents\ArcGIS\Projects\MIMS\MIMS.gdb"
#fc = r"C:\Users\friendde\Documents\ArcGIS\Projects\MIMS\MIMS.gdb\ActiveBusiness\ActiveBusinessCity"
tbl = r"C:\Users\friendde\Documents\ArcGIS\Projects\MIMS\MIMS.gdb\BusinessCity"
#flds = ['BusinessName','BusinessPhone','BusinessType','BusinessAddress','BusinessOwner','POINT_X','POINT_Y','SHAPE@XY']
flds = ['BusinessName','BusinessPhone','BusinessType','BusinessAddress','BusinessOwner','POINT_X','POINT_Y']
location = [0,0]
tupleXY = (0,0)

# %%
arcpy.env.workspace = gdb
arcpy.env.overwriteOutput = True
#arcpy.env.outputCoordinateSystem = arcpy.SpatialReference(4326)

# %%
def getCoords(_dict):
    if _dict is None:
        return [0,0]
    else:
        #print(_dict.get('coordinates'))
        return _dict.get('coordinates')

# %%
http = urllib3.PoolManager()
response = http.request('GET', jsonURL)
#response.status
#response.data

# %%
data = json.loads(response.data)

# %%
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "28789",
#     "name": "USF & G INSURANCE CO.",
#     "start_date": "2002-10-03T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "ONE TOWER SQUARE",
#     "mailing_city": "HARTFORD",
#     "mailing_state": "CT",
#     "mailing_zip_code": "06183",
#     "business_phone": "860-277-0111",
#     "email": "DESMITH@TRAVELERS.COM",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "41314",
#     "name": "MUNDEN, BETH",
#     "start_date": "2014-10-20T00:00:00.000",
#     "physical_address": "2124 SW 34TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4651 NE 155TH TER",
#     "mailing_city": "WILLISTON",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32696",
#     "business_phone": "352-377-8049",
#     "owner": "BETH  MUNDEN",
#     "latitude": "29.63267",
#     "longitude": "-82.372618",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.372618,
#         29.63267
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "7",
#     ":@computed_region_e6r8_dw75": "20",
#     ":@computed_region_u9vc_vmbc": "12",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "7",
#     ":@computed_region_ndi2_bfht": "12"
#   },
#   {
#     "business_type": "AUTO REPAIR GARAGE",
#     "id": "20362",
#     "name": "STUART S CYCLE",
#     "start_date": "1995-09-13T00:00:00.000",
#     "physical_address": "217 NE 16TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "217 NE 16TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-373-6502",
#     "owner": "ROLAND  STUART",
#     "latitude": "29.6666",
#     "longitude": "-82.323022",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.323022,
#         29.6666
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "13",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "ATTORNEY/LAWYER",
#     "id": "42003",
#     "name": "HUTCHISON PLLC",
#     "start_date": "2015-10-03T00:00:00.000",
#     "physical_address": "101 SE 2ND PL, #E201D",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "101 SE 2ND PL, #E201D",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "919-829-4301",
#     "email": "RGIDDINGS@HUTCHLAW.COM",
#     "owner": "HUTCHISON PLLC",
#     "latitude": "29.649653",
#     "longitude": "-82.323731",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.323731,
#         29.649653
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "43449",
#     "name": "BUI, NGA",
#     "start_date": "2016-08-10T00:00:00.000",
#     "physical_address": "5230 SW 34TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "9441 NW 23RD RD",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32606",
#     "business_phone": "352-269-3494",
#     "owner": "NGA  BUI",
#     "latitude": "29.603099",
#     "longitude": "-82.37069",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.37069,
#         29.603099
#       ]
#     },
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "26",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "BARBER SHOP",
#     "id": "25061",
#     "name": "FADES & FROS",
#     "start_date": "1999-06-15T00:00:00.000",
#     "physical_address": "600 NW 5TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "600 NW 5TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-384-1008",
#     "owner": "WARREN  SCOTT",
#     "latitude": "29.655654",
#     "longitude": "-82.331026",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.331026,
#         29.655654
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BARBER SHOP",
#     "id": "25061",
#     "name": "FADES & FROS",
#     "start_date": "1999-06-15T00:00:00.000",
#     "physical_address": "600 NW 5TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "600 NW 5TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-384-1008",
#     "owner": "WARREN  SCOTT",
#     "latitude": "29.655654",
#     "longitude": "-82.331026",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.331026,
#         29.655654
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "43449",
#     "name": "BUI, NGA",
#     "start_date": "2016-08-10T00:00:00.000",
#     "physical_address": "5230 SW 34TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "9441 NW 23RD RD",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32606",
#     "business_phone": "352-269-3494",
#     "owner": "NGA  BUI",
#     "latitude": "29.603099",
#     "longitude": "-82.37069",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.37069,
#         29.603099
#       ]
#     },
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "26",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "BEAUTY PARLOR",
#     "id": "25375",
#     "name": "MILLHOPPER HAIR DESIGN.",
#     "start_date": "1999-09-01T00:00:00.000",
#     "physical_address": "4129 NW 16TH BLVD",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4129 NW 16TH BLVD",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-371-1200",
#     "owner": "HA  AU",
#     "latitude": "29.673053",
#     "longitude": "-82.386838",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.386838,
#         29.673052999999996
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "35",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "6",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "CONTRACTOR-INSTALLATION",
#     "id": "18779",
#     "name": "QUALITY SERVICE-STEPHEN SCOTT, INC",
#     "start_date": "1995-10-13T00:00:00.000",
#     "physical_address": "1901 NW 67TH PL, STE. J",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1901 NW 67TH PL, STE. J",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32653",
#     "business_phone": "352-377-4939",
#     "email": "HOUSEDOCTORS123@BELLSOUTH.NET",
#     "owner": "QUALITY SERVICE-STEPHEN SCOTT, INC",
#     "latitude": "29.715926",
#     "longitude": "-82.34715",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.34715,
#         29.715926
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "10",
#     ":@computed_region_e6r8_dw75": "31",
#     ":@computed_region_u9vc_vmbc": "7",
#     ":@computed_region_4rat_gsiv": "1079",
#     ":@computed_region_43jd_v64e": "1",
#     ":@computed_region_ndi2_bfht": "7"
#   },
#   {
#     "business_type": "CONTRACTOR-INSTALLATION",
#     "id": "23293",
#     "name": "NETWORK SERVICES, INC",
#     "start_date": "1997-07-09T00:00:00.000",
#     "physical_address": "900 NW 8TH AVE, STE F",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "900 NW 8TH AVE, STE F",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-336-3336",
#     "email": "nsinfo@networkservinc.com",
#     "owner": "NETWORK SERVICES INC.",
#     "latitude": "29.659406",
#     "longitude": "-82.334304",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.334304,
#         29.659405999999997
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "CONTRACTOR-INSTALLATION",
#     "id": "30797",
#     "name": "STIRIZ, KEITH",
#     "start_date": "2016-08-15T00:00:00.000",
#     "physical_address": "8345 NW 54TH TER",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "8345 NW 54TH TER",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32653",
#     "business_phone": "352-262-2834",
#     "owner": "WOOD RENEWAL DONE RIGHT",
#     "latitude": "29.731462",
#     "longitude": "-82.402282",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.402282,
#         29.731462
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "10",
#     ":@computed_region_e6r8_dw75": "40",
#     ":@computed_region_u9vc_vmbc": "5",
#     ":@computed_region_4rat_gsiv": "1079",
#     ":@computed_region_43jd_v64e": "2",
#     ":@computed_region_ndi2_bfht": "5"
#   },
#   {
#     "business_type": "CONTRACTOR-BUILDING",
#     "id": "30435",
#     "name": "DELOACH, ROY EDWARD",
#     "start_date": "2004-04-08T00:00:00.000",
#     "physical_address": "444 NW 28TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "444 NW 28TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32609",
#     "business_phone": "352-316-4852",
#     "owner": "QUALITY CARPENTRY OF NORTH FLA., INC",
#     "latitude": "29.677996",
#     "longitude": "-82.329072",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.329072,
#         29.677996
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "3",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "10",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "CATALOGUE OR MAIL ORDER SERVICE",
#     "id": "30431",
#     "name": "FRAZIER, ROBERT L., III",
#     "start_date": "2004-04-30T00:00:00.000",
#     "physical_address": "1309 NE 28TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1309 NE 28TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32609",
#     "business_phone": "352-538-7214",
#     "email": "info@comfort4u.net",
#     "owner": "ROBERT  FRAZIER III",
#     "latitude": "29.677536",
#     "longitude": "-82.309073",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.309073,
#         29.677536
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "12",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "10",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "COIN-OP VENDING MACHINES",
#     "id": "43734",
#     "name": "GAINESVILLE LAUNDRY, INC.",
#     "start_date": "2019-02-13T00:00:00.000",
#     "physical_address": "2430 N MAIN ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "923 N MAGNOLIA AVE, SUITE 402",
#     "mailing_city": "OCALA",
#     "mailing_state": "FL",
#     "mailing_zip_code": "34475",
#     "business_phone": "866-352-9274",
#     "email": "INVOICES@SPINCITYOCALA.COM",
#     "owner": "GAINESVILLE LAUNDRY, INC.",
#     "latitude": "29.674824",
#     "longitude": "-82.32102",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.32102,
#         29.674824
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "12",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "10",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "BEAUTY PARLOR",
#     "id": "17802",
#     "name": "NEW ATTRACTION, THE",
#     "start_date": "1984-11-01T00:00:00.000",
#     "physical_address": "1410 NW 13TH ST, SUITE 4",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1410 NW 13TH ST, SUITE 4",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-371-0050",
#     "owner": "GLORIA  ROLLINS",
#     "latitude": "29.665458",
#     "longitude": "-82.339162",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.339162,
#         29.665458000000005
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "2",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "5",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "BOOKKEEPING OR INCOME TAX SERVICE",
#     "id": "32343",
#     "name": "H & R BLOCK",
#     "start_date": "2005-01-01T00:00:00.000",
#     "physical_address": "1507 NW 23RD AVE, STES. 1 & 2",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "ONE H&R BLOCK WAY",
#     "mailing_city": "KANSAS CITY",
#     "mailing_state": "MO",
#     "mailing_zip_code": "64105",
#     "business_phone": "877-880-5222",
#     "email": "OCOEBUSINESSLICENSE@HRBLOCK.COM",
#     "owner": "HRB TAX GROUP, INC.",
#     "latitude": "29.673987",
#     "longitude": "-82.34123",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.34123,
#         29.673987
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "8",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "3",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "CONSULTANT",
#     "id": "43825",
#     "name": "NORMAN, CATHY R",
#     "start_date": "2019-04-19T00:00:00.000",
#     "physical_address": "1226 SE 17TH DR",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "PO BOX 142731",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32614",
#     "business_phone": "352-213-2466",
#     "email": "INFO@INTUITIVEDESIGNCLOTHING.COM",
#     "owner": "CATHY R NORMAN",
#     "latitude": "29.639452",
#     "longitude": "-82.301969",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.30196900000001,
#         29.639452
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "9",
#     ":@computed_region_e6r8_dw75": "5",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "1082",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "18",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "CONTRACTOR-GAS PIPE INSTALLATION",
#     "id": "38648",
#     "name": "PITTMAN, CLAYTON R.",
#     "start_date": "2010-11-04T00:00:00.000",
#     "physical_address": "3741 NW 21ST DR",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3741 NW 21ST DR",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-318-1276",
#     "email": "PITTMANCLAYTON@YAHOO.COM",
#     "owner": "TIGHT LINES GAS SERVICE L.L.C.",
#     "latitude": "29.687878",
#     "longitude": "-82.353169",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.353169,
#         29.687878000000005
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "18",
#     ":@computed_region_u9vc_vmbc": "7",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "3",
#     ":@computed_region_ndi2_bfht": "7"
#   },
#   {
#     "business_type": "COMPUTER ANALYSTS",
#     "id": "25686",
#     "name": "STREAMLINE NUMERICS, INC.",
#     "start_date": "2000-01-01T00:00:00.000",
#     "physical_address": "3221 NW 13TH ST, STE. A",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3221 NW 13TH ST, STE. A",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32609",
#     "business_phone": "352-271-8841",
#     "email": "JEFFWRIGHT83@GMAIL.COM",
#     "owner": "STREAMLINE NUMERICS, INC.",
#     "latitude": "29.68263",
#     "longitude": "-82.338992",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.338992,
#         29.682629999999996
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "3",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "3",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "BOOKKEEPING OR INCOME TAX SERVICE",
#     "id": "39315",
#     "name": "TAX SERVICES OF AMERICA, INC.",
#     "start_date": "2011-10-03T00:00:00.000",
#     "physical_address": "01800 NE 12TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "ATTN: MARIA SATTIZAHN, P O BOX 941290",
#     "mailing_city": "MAITLAND",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32794",
#     "business_phone": "407-691-0004",
#     "email": "JH.BLIC@GULFSTREAMTAXGROUP.COM",
#     "owner": "TAX SERVICES OF AMERICA, INC.",
#     "latitude": "29.661941",
#     "longitude": "-82.300747",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.300747,
#         29.661940999999995
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "9",
#     ":@computed_region_e6r8_dw75": "14",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "1082",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "12",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "CATALOGUE OR MAIL ORDER SERVICE",
#     "id": "33945",
#     "name": "WIKISIO INC",
#     "start_date": "2006-09-01T00:00:00.000",
#     "physical_address": "4445 SW 35TH TER, SUITE 460",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4601 HAINES RD N",
#     "mailing_city": "SAINT PETERSBURG",
#     "mailing_state": "FL",
#     "mailing_zip_code": "33714",
#     "business_phone": "352-338-1121",
#     "email": "SHOP@ONEGREEKSTORE.COM",
#     "owner": "WIKISIO INC",
#     "latitude": "29.612241",
#     "longitude": "-82.375141",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.375141,
#         29.612241000000004
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "21",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "9",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "BOOKKEEPING OR INCOME TAX SERVICE",
#     "id": "43220",
#     "name": "MINK & AGARWAL, PLLC",
#     "start_date": "2018-02-26T00:00:00.000",
#     "physical_address": "5200 W NEWBERRY RD, D-4",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "5200 W NEWBERRY RD, D-4",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32607",
#     "business_phone": "352-535-0059",
#     "email": "BASANTAGARWAL@YAHOO.COM",
#     "owner": "MINK & AGARWAL, PLLC",
#     "latitude": "29.659066867000035",
#     "longitude": "-82.39929548399994",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.39929548399994,
#         29.659066867000035
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "27",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "768",
#     ":@computed_region_43jd_v64e": "4",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "CONTRACTOR-INSTALLATION",
#     "id": "41692",
#     "name": "ADVANCED AUTOMATION SYSTEMS, INC",
#     "start_date": "2015-08-01T00:00:00.000",
#     "physical_address": "4641 NW 6TH ST, STE F",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3802 N 40TH ST",
#     "mailing_city": "TAMPA",
#     "mailing_state": "FL",
#     "mailing_zip_code": "33610",
#     "business_phone": "813-621-8257",
#     "email": "BLABARGE@AASDIFFERENCE.COM",
#     "owner": "ADVANCED AUTOMATION SYSTEMS, INC",
#     "latitude": "29.698032",
#     "longitude": "-82.334635",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.334635,
#         29.698032
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "10",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_9cfm_spy5": "4",
#     ":@computed_region_43jd_v64e": "10",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "BEAUTY PARLOR",
#     "id": "40096",
#     "name": "SMARTSTYLE #3976",
#     "start_date": "2013-02-01T00:00:00.000",
#     "physical_address": "5700 NW 23RD ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "7201 METRO BLVD",
#     "mailing_city": "MINNEAPOLIS",
#     "mailing_state": "MN",
#     "mailing_zip_code": "55439",
#     "business_phone": "352-375-2344",
#     "owner": "MINNESOTA REGIS CORP",
#     "latitude": "29.708854",
#     "longitude": "-82.355728",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.355728,
#         29.708854000000002
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "10",
#     ":@computed_region_e6r8_dw75": "37",
#     ":@computed_region_u9vc_vmbc": "7",
#     ":@computed_region_4rat_gsiv": "1079",
#     ":@computed_region_43jd_v64e": "1",
#     ":@computed_region_ndi2_bfht": "7"
#   },
#   {
#     "business_type": "CONSULTANT",
#     "id": "35000",
#     "name": "SMITH, ERICK, MEISENBURG, MICHAEL",
#     "start_date": "2007-08-06T00:00:00.000",
#     "physical_address": "915 NW 17TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "PO BOX 12417",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32604",
#     "business_phone": "352-380-0648",
#     "email": "erick@kestreleco.com",
#     "owner": "KESTREL ECOLOGICAL SERVICES LLC",
#     "latitude": "29.667545",
#     "longitude": "-82.334642",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.334642,
#         29.667545
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "2",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "3",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "BUSINESS BROKER",
#     "id": "43077",
#     "name": "GUITAR HOUSE, THE",
#     "start_date": "2017-10-20T00:00:00.000",
#     "physical_address": "215 SW 3RD AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1923 NW 23RD BLVD, APT 213",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-222-7102",
#     "email": "CALEB@THEGUITARHOUSE.COM",
#     "owner": "THE GUITAR HOUSE LLC",
#     "latitude": "29.648979",
#     "longitude": "-82.327163",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.327163,
#         29.648979000000004
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BUSINESS OFFICE NOT OTHERWISE TAXED",
#     "id": "41693",
#     "name": "SHERIDAN HEALTHCORP INC.",
#     "start_date": "2015-07-01T00:00:00.000",
#     "physical_address": "4500 W NEWBERRY RD",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "7700 W SUNRISE BLVD, 2ND FLOOR",
#     "mailing_city": "PLANTATION",
#     "mailing_state": "FL",
#     "mailing_zip_code": "33322",
#     "business_phone": "954-939-6842",
#     "email": "JASMINE.KHAN@SHCR.COM",
#     "owner": "SHERIDAN  HEALTHCORP INC.",
#     "latitude": "29.656652055000052",
#     "longitude": "-82.39234130999995",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.39234130999995,
#         29.656652055000052
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "27",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "4",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "CONTRACTOR-GENERAL-UNLIMITED",
#     "id": "28431",
#     "name": "EMMER DEVELOPMENT CORP.",
#     "start_date": "2002-10-01T00:00:00.000",
#     "physical_address": "2801 SW ARCHER RD",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "2801 SW ARCHER RD",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32608",
#     "business_phone": "352-376-2444",
#     "email": "AP@EMMERGROUP.COM",
#     "owner": "EMMER DEVELOPMENT CORP",
#     "latitude": "29.630591",
#     "longitude": "-82.365062",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.365062,
#         29.630591
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "23",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "8",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "CATERER",
#     "id": "43771",
#     "name": "BURRITO FAMOUS",
#     "start_date": "2019-03-01T00:00:00.000",
#     "physical_address": "3412 W UNIVERSITY AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3412 W UNIVERSITY AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32607",
#     "business_phone": "352-672-6654",
#     "email": "EDGAR@BURRITOFAMOUS.COM",
#     "owner": "TOP DOG  TACO COMPANY LLC",
#     "latitude": "29.652063",
#     "longitude": "-82.37298",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.37298000000001,
#         29.652062999999995
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "7",
#     ":@computed_region_e6r8_dw75": "33",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "768",
#     ":@computed_region_43jd_v64e": "4",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "BEAUTY PARLOR",
#     "id": "35358",
#     "name": "MODE SALON  AND ANTI-AGING SPA LLC",
#     "start_date": "2013-04-23T00:00:00.000",
#     "physical_address": "603 E UNIVERSITY AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "603 E UNIVERSITY AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-374-3883",
#     "email": "danny@amodesalon.com",
#     "owner": "MODE SALON AND ANTI-AGING SPA LLC",
#     "latitude": "29.651937",
#     "longitude": "-82.31897",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.31897,
#         29.651937
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "17",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "CONTRACTOR-MECHANICAL",
#     "id": "14440",
#     "name": "GAY, W. W., MECHANICAL CONTRACTOR, INC.",
#     "start_date": "1995-10-02T00:00:00.000",
#     "physical_address": "515 SE 11TH PL",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "524  STOCKTON ST",
#     "mailing_city": "JACKSONVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32204",
#     "business_phone": "904-388-2696",
#     "email": "TCAMP@WWGMC.COM",
#     "owner": "WILLIAM  GAY",
#     "latitude": "29.640286",
#     "longitude": "-82.317734",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.317734,
#         29.640286
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "5",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "17",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "CONTRACTOR-PAINTER/PAPERHANGER",
#     "id": "39655",
#     "name": "BARKERBRUSHWORKS",
#     "start_date": "2012-05-14T00:00:00.000",
#     "physical_address": "2160 NE 1ST BLVD, # 9",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "2308 NE 14TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32609",
#     "business_phone": "352-372-0256",
#     "owner": "RONALD G BARKER",
#     "latitude": "29.672823",
#     "longitude": "-82.323803",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.323803,
#         29.672823000000005
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "2",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_43jd_v64e": "10",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "CONTRACTOR-PAINTER/PAPERHANGER",
#     "id": "41492",
#     "name": "SUMPTER, FRANK",
#     "start_date": "2015-03-16T00:00:00.000",
#     "physical_address": "619 NE 18TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "619 NE 18TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32641",
#     "business_phone": "352-231-3055",
#     "owner": "FRANK  SUMPTER",
#     "latitude": "29.657335",
#     "longitude": "-82.301698",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.301698,
#         29.657335000000003
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "9",
#     ":@computed_region_e6r8_dw75": "14",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "1082",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "12",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "CONTRACTOR-PAINTER/PAPERHANGER",
#     "id": "41492",
#     "name": "SUMPTER, FRANK",
#     "start_date": "2015-03-16T00:00:00.000",
#     "physical_address": "619 NE 18TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "619 NE 18TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32641",
#     "business_phone": "352-231-3055",
#     "owner": "FRANK  SUMPTER",
#     "latitude": "29.657335",
#     "longitude": "-82.301698",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.301698,
#         29.657335000000003
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "9",
#     ":@computed_region_e6r8_dw75": "14",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "1082",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "12",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "41212",
#     "name": "AMFIRST INSURANCE COMPANY",
#     "start_date": "2014-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "5722 I-55 NORTH FRONTAGE ROAD",
#     "mailing_city": "JACKSON",
#     "mailing_state": "MS",
#     "mailing_zip_code": "39211",
#     "business_phone": "601-956-2028",
#     "owner": "AMFIRST  INSURANCE COMPANY",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "FUNERAL HOME",
#     "id": "13290",
#     "name": "DUNCAN BROTHERS FUNERAL HOME",
#     "start_date": "1995-09-21T00:00:00.000",
#     "physical_address": "428 NW 8TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "428 NW 8TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-376-2437",
#     "latitude": "29.655313",
#     "longitude": "-82.332922",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.332922,
#         29.655312999999996
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "PEDDLER",
#     "id": "43594",
#     "name": "HENDERSON, WARREN G.",
#     "start_date": "2018-10-29T00:00:00.000",
#     "physical_address": "MOBILE ONLY",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "PO BOX 663",
#     "mailing_city": "HAWTHORNE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32640",
#     "business_phone": "352-215-6358",
#     "email": "WGHENDERSON@GMAIL.COM",
#     "owner": "WARREN G HENDERSON",
#     "latitude": "29.635270044000038",
#     "longitude": "-82.27217992699997",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.27217992699997,
#         29.635270044000038
#       ]
#     },
#     ":@computed_region_ecgy_hwrz": "9",
#     ":@computed_region_e6r8_dw75": "19",
#     ":@computed_region_u9vc_vmbc": "8",
#     ":@computed_region_4rat_gsiv": "1082",
#     ":@computed_region_ndi2_bfht": "8"
#   },
#   {
#     "business_type": "INSURANCE AGENT -1 AGENT",
#     "id": "20576",
#     "name": "TABER, STEVE",
#     "start_date": "1978-01-01T00:00:00.000",
#     "physical_address": "5310 NW 8TH AVE, STE. 1",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "5310 NW 8TH AVE, STE. 1",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-377-9819",
#     "owner": "J.  STEPHEN  TABER",
#     "latitude": "29.659601",
#     "longitude": "-82.400286",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.400286,
#         29.659601
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "35",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "768",
#     ":@computed_region_43jd_v64e": "6",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "22837",
#     "name": "GENERAL CASUALTY INSURANCE CO.",
#     "start_date": "1996-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "ONE GENERAL DR",
#     "mailing_city": "SUN PRAIRIE",
#     "mailing_state": "WI",
#     "mailing_zip_code": "53596",
#     "business_phone": "608-837-4440",
#     "owner": "KEN  SATO",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "42418",
#     "name": "EAGLE LIFE INSURANCE COMPANY",
#     "start_date": "2016-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "6000 WESTOWN PKWY",
#     "mailing_city": "WEST DES MOINES",
#     "mailing_state": "IA",
#     "mailing_zip_code": "50266",
#     "business_phone": "515-273-3796",
#     "email": "STATEFILINGS@AMERICAN-EQUITY.COM",
#     "owner": "EAGLE  LIFE INSURANCE COMPANY",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "39322",
#     "name": "EMPLOYERS INSURANCE CO. OF WAUSAU",
#     "start_date": "2011-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "175 BERKELEY ST",
#     "mailing_city": "BOSTON",
#     "mailing_state": "MA",
#     "mailing_zip_code": "02116",
#     "business_phone": "617-357-9500",
#     "email": "LISA.REDDICK@LIBERTYMUTUAL.COM",
#     "owner": "EMPLOYERS INSURANCE CO. OF WAUSAU",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "43914",
#     "name": "EQUITY INSURANCE COMPANY",
#     "start_date": "2016-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4315 LAKE SHORE DR, STE J",
#     "mailing_city": "WACO",
#     "mailing_state": "TX",
#     "mailing_zip_code": "76710",
#     "business_phone": "254-776-4521",
#     "owner": "EQUITY  INSURANCE COMPANY",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "39029",
#     "name": "EXECUTIVE RISK INDEMNITY INC",
#     "start_date": "2010-08-09T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "15 MOUNTAIN VIEW RD",
#     "mailing_city": "WARREN",
#     "mailing_state": "NJ",
#     "mailing_zip_code": "07059",
#     "business_phone": "908-572-5380",
#     "email": "AGENCY-SERVICES@CHUBB.COM",
#     "owner": "CORPORATION  EXECUTIVE RISK INDEMNITY INC",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "15044",
#     "name": "HARTFORD LIFE INSURANCE CO",
#     "start_date": "1995-09-25T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "ONE HARTFORD PLAZA",
#     "mailing_city": "HARTFORD",
#     "mailing_state": "CT",
#     "mailing_zip_code": "06155",
#     "business_phone": "860-547-9907",
#     "email": "TAXSTATEUNIT@THEHARTFORD.COM",
#     "owner": "HARTFORD LIFE INSURANCE CO",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "14961",
#     "name": "HARCO NATIONAL INS. CO.",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "702 OBERLIN ROAD",
#     "mailing_city": "RALEIGH",
#     "mailing_state": "NC",
#     "mailing_zip_code": "27605",
#     "business_phone": "919-833-1600",
#     "owner": "R.P.O.",
#     "latitude": "29.651950000000056",
#     "longitude": "-82.32277999999997",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.32277999999997,
#         29.65195000000006
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "43558",
#     "name": "PHARMACISTS MUTUAL INSURANCE COMPANY",
#     "start_date": "2018-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "PO BOX 370",
#     "mailing_city": "ALGONA",
#     "mailing_state": "IA",
#     "mailing_zip_code": "50511",
#     "business_phone": "515-295-2461",
#     "owner": "PHARAMSISTS  MUTAL INSURANCE COMPANY",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "30984",
#     "name": "REGENT INSURANCE CO.",
#     "start_date": "2004-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1   GENERAL DR",
#     "mailing_city": "SUN PRAIRIE",
#     "mailing_state": "WI",
#     "mailing_zip_code": "53596",
#     "business_phone": "608-837-4440",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "42428",
#     "name": "ZURICH AMERICAN LIFE INSURANCE CO.",
#     "start_date": "2016-10-01T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1299 ZURICH WAY",
#     "mailing_city": "SCHAUMBURG",
#     "mailing_state": "IL",
#     "mailing_zip_code": "60196",
#     "business_phone": "877-301-5376",
#     "email": "KATE.PEC@ZURICH.COM",
#     "owner": "ZURICH AMERICAN LIFE INSURANCE CO.",
#     "latitude": "32.81827747900007",
#     "longitude": "-88.16359175399998",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -88.16359175399998,
#         32.81827747900007
#       ]
#     }
#   },
#   {
#     "business_type": "LAUNDRY FACILITY",
#     "id": "42001",
#     "name": "MHR CLEANER INC",
#     "start_date": "2016-01-18T00:00:00.000",
#     "physical_address": "2411 SW 13TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "2411 SW 13TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-336-0720",
#     "email": "HETMAYANK@YAHOO.COM",
#     "owner": "MHR CLEANER INC",
#     "latitude": "29.629615",
#     "longitude": "-82.339264",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.339264,
#         29.629615
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "15",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "16",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "LABORATORY (DENTAL)",
#     "id": "16868",
#     "name": "MARCHAND, JEFF S.",
#     "start_date": "1991-06-01T00:00:00.000",
#     "physical_address": "3311 NW 29TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3311 NW 29TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-514-6316",
#     "owner": "JEFF  MARCHAND",
#     "latitude": "29.67925",
#     "longitude": "-82.371546",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.371546,
#         29.679249999999996
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "8",
#     ":@computed_region_u9vc_vmbc": "7",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "3",
#     ":@computed_region_ndi2_bfht": "7"
#   },
#   {
#     "business_type": "MANUFACTURING-FOOD PRODUCTS",
#     "id": "43264",
#     "name": "BRIO CAFE, LLC",
#     "start_date": "2018-04-02T00:00:00.000",
#     "physical_address": "213 NW 10TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "618 S MAIN ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-857-7858",
#     "email": "BRIOCOLDBREW@GMAIL.COM",
#     "owner": "BRIO CAFE, LLC",
#     "latitude": "29.661104",
#     "longitude": "-82.32679",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.32679,
#         29.661104
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "2",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "INSURANCE COMPANY OR BROKER",
#     "id": "20229",
#     "name": "STAR INSURANCE CO.",
#     "start_date": "1995-09-25T00:00:00.000",
#     "physical_address": "OUT OF STATE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "26255 AMERICAN DR",
#     "mailing_city": "SOUTHFIELD",
#     "mailing_state": "MI",
#     "mailing_zip_code": "48034",
# ...
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "28390",
#     "name": "SUMMER PLACE APARTMENTS",
#     "start_date": "2002-10-01T00:00:00.000",
#     "physical_address": "3316 SW 41ST PL",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "P O BOX 358778",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32635",
#     "business_phone": "352-373-2818",
#     "email": "GREMCO@GREMCO.COM",
#     "owner": "SUMMER PLACE APTS., LTD.",
#     "latitude": "29.615581",
#     "longitude": "-82.370862",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.370862,
#         29.615581
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "24",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "8",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "36326",
#     "name": "COLONIAL OAKS",
#     "start_date": "2009-06-01T00:00:00.000",
#     "physical_address": "4241 SW 21ST PL",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "220 N MAIN ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-375-2152",
#     "email": "PINETREEGARDENS@COLLIERCOMPANIES.COM",
#     "owner": "COLONIAL  OAKS APARTMENTS LLC",
#     "latitude": "29.632759",
#     "longitude": "-82.38859",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.38859,
#         29.632759
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "7",
#     ":@computed_region_e6r8_dw75": "32",
#     ":@computed_region_u9vc_vmbc": "12",
#     ":@computed_region_4rat_gsiv": "768",
#     ":@computed_region_43jd_v64e": "7",
#     ":@computed_region_ndi2_bfht": "12"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "41822",
#     "name": "ROSA, MELANIE",
#     "start_date": "2015-10-05T00:00:00.000",
#     "physical_address": "603 W UNIVERSITY AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "2949 SW 39TH AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32608",
#     "business_phone": "407-221-9187",
#     "email": "MELANIEPAIGE143@GMAIL.COM",
#     "owner": "MELANIE  ROSA",
#     "latitude": "29.65200748500007",
#     "longitude": "-82.33093408699995",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.33093408699995,
#         29.65200748500007
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "11147",
#     "name": "BENNETT, MICHAEL",
#     "start_date": "1996-02-14T00:00:00.000",
#     "physical_address": "5200 NW 43RD ST, SUITE 301",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "5200 NW 43RD ST, SUITE 301",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32606",
#     "business_phone": "352-372-5263",
#     "email": "MHBENNETT@GMAIL.COM",
#     "owner": "MICHAEL  BENNETT",
#     "latitude": "29.701902",
#     "longitude": "-82.388953",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.388953,
#         29.701902
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "6",
#     ":@computed_region_e6r8_dw75": "38",
#     ":@computed_region_u9vc_vmbc": "5",
#     ":@computed_region_4rat_gsiv": "769",
#     ":@computed_region_43jd_v64e": "2",
#     ":@computed_region_ndi2_bfht": "5"
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "40584",
#     "name": "CROSS KEYS PROPERTIES LLC",
#     "start_date": "2013-01-01T00:00:00.000",
#     "physical_address": "821 NW 13TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "907 NW 13TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-505-5049",
#     "email": "JENNIFER@CROSSKEYSPROPERTIES.COM",
#     "owner": "CROSS KEYS PROPERTIES LLC",
#     "latitude": "29.659961",
#     "longitude": "-82.339171",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.339171,
#         29.659961
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "2",
#     ":@computed_region_u9vc_vmbc": "4",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "4"
#   },
#   {
#     "business_type": "ARCHITECT",
#     "id": "19074",
#     "name": "RICKMAN, PHILIP E., ARCHITECT",
#     "start_date": "1992-06-26T00:00:00.000",
#     "physical_address": "4328 NW 29TH TER",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4328 NW 29TH TER",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32605",
#     "business_phone": "352-377-7359",
#     "email": "RICKMANPARTNERSHIP@ATT.NET",
#     "owner": "RICKMAN  PARTNERSHIP, INC., THE",
#     "latitude": "29.69417",
#     "longitude": "-82.366868",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.366868,
#         29.69417
#       ]
#     },
#     ":@computed_region_axii_i744": "2",
#     ":@computed_region_ecgy_hwrz": "5",
#     ":@computed_region_e6r8_dw75": "18",
#     ":@computed_region_u9vc_vmbc": "7",
#     ":@computed_region_4rat_gsiv": "770",
#     ":@computed_region_43jd_v64e": "2",
#     ":@computed_region_ndi2_bfht": "7"
#   },
#   {
#     "business_type": "AUTO PAINTING, UPHOLSTERY OR TOP SHOP",
#     "id": "32006",
#     "name": "AUTOMOTIVE SUPER SPORTS INC.",
#     "start_date": "2004-10-29T00:00:00.000",
#     "physical_address": "3001 NE 21ST WAY, BLDG A",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3001 NE 21ST WAY, BLDG A",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32609",
#     "business_phone": "352-379-9111",
#     "email": "AUTOPB2000@YAHOO.COM",
#     "owner": "AUTOMOTIVE SUPER SPORTS INC",
#     "latitude": "29.680101",
#     "longitude": "-82.294855",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.294855,
#         29.680101
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "4",
#     ":@computed_region_e6r8_dw75": "12",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "766",
#     ":@computed_region_9cfm_spy5": "3",
#     ":@computed_region_43jd_v64e": "11",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "35767",
#     "name": "SAN MITCHELL APARTMENTS",
#     "start_date": "1994-09-01T00:00:00.000",
#     "physical_address": "1931 NW 4TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "909 NW 6TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-378-1387",
#     "email": "RABELL@ATLANTIC.NET",
#     "owner": "IVO S RABELL  & FRANCISCO RABELL",
#     "latitude": "29.654880518000027",
#     "longitude": "-82.34874080699996",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.34874080699996,
#         29.654880518000027
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "3",
#     ":@computed_region_e6r8_dw75": "16",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "771",
#     ":@computed_region_43jd_v64e": "5",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "ASSISTED LIVING FACILITY",
#     "id": "34838",
#     "name": "SOUTHWEST RETIREMENT HOME, INC.",
#     "start_date": "2007-04-19T00:00:00.000",
#     "physical_address": "3207 SW 42ND PL",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "3207 SW 42ND PL",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32608",
#     "business_phone": "352-338-0252",
#     "email": "SWRETIREMENTHOME@GMAIL.COM",
#     "owner": "CORPORATION  SOUTHWEST RETIREMENT HOME, INC",
#     "latitude": "29.614178",
#     "longitude": "-82.36968",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.36968,
#         29.614178
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "24",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "8",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "32713",
#     "name": "ARBOR EAST APARTMENTS",
#     "start_date": "2005-07-13T00:00:00.000",
#     "physical_address": "2335 SW 35TH PL",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "13400 PROGRESS BLVD",
#     "mailing_city": "ALACHUA",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32615",
#     "business_phone": "352-505-6966",
#     "email": "CORPORATE@CMCAPT.COM",
#     "owner": "ARBOR VILLAS EAST, LLC",
#     "latitude": "29.620095",
#     "longitude": "-82.358",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.358,
#         29.620095
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "23",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_43jd_v64e": "8",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "43446",
#     "name": "BUI, JINA",
#     "start_date": "2017-07-21T00:00:00.000",
#     "physical_address": "5230 SW 34TH ST",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "12428 SW ARCHER RD",
#     "mailing_city": "ARCHER",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32618",
#     "business_phone": "352-692-4394",
#     "email": "TRAMBUI909@GMAIL.COM",
#     "owner": "JINA  BUI",
#     "latitude": "29.603099",
#     "longitude": "-82.37069",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.37069,
#         29.603099
#       ]
#     },
#     ":@computed_region_ecgy_hwrz": "2",
#     ":@computed_region_e6r8_dw75": "26",
#     ":@computed_region_u9vc_vmbc": "3",
#     ":@computed_region_4rat_gsiv": "767",
#     ":@computed_region_ndi2_bfht": "3"
#   },
#   {
#     "business_type": "APARTMENT OR CONDO RENTALS",
#     "id": "41730",
#     "name": "LATITUDE 29 APARTMENTS",
#     "start_date": "2014-12-01T00:00:00.000",
#     "physical_address": "1016 SW 8TH AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "321 SW 13TH ST",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-376-6223",
#     "email": "CLARSEN@TRIMARKPROPERTIES.COM",
#     "owner": "GAINESVILLE HISTORIC PROPERTIES LLC",
#     "latitude": "29.644907",
#     "longitude": "-82.335725",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.335725,
#         29.644907
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "1",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "ATTORNEY/LAWYER",
#     "id": "17114",
#     "name": "MCGURN, LINDA",
#     "start_date": "1995-09-20T00:00:00.000",
#     "physical_address": "101 SE 2ND PL, SUITE 202",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "101 SE 2ND PLACE, #202",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-372-6172",
#     "email": "LINDA@MCGURN.COM",
#     "owner": "LINDA  MCGURN",
#     "latitude": "29.649653",
#     "longitude": "-82.323731",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.323731,
#         29.649653
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "15",
#     ":@computed_region_ndi2_bfht": "1"
#   },
#   {
#     "business_type": "BARBER/COSMETOLOGIST/NAIL TECH",
#     "id": "43462",
#     "name": "NATTIEL, REGINALD",
#     "start_date": "2018-08-02T00:00:00.000",
#     "physical_address": "1152 NE 16TH AVE, STE B",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "1411 SE 3RD AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32641",
#     "business_phone": "352-538-5524",
#     "email": "alycia.nattiel@yahoo.com",
#     "owner": "REGINALD  NATTIEL",
#     "latitude": "29.666535",
#     "longitude": "-82.31075",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.31075,
#         29.666535
#       ]
#     },
#     ":@computed_region_axii_i744": "4",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "2",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_43jd_v64e": "13",
#     ":@computed_region_ndi2_bfht": "2"
#   },
#   {
#     "business_type": "ATTORNEY/LAWYER",
#     "id": "34511",
#     "name": "SILVERMAN & MACK, LLC",
#     "start_date": "2007-01-02T00:00:00.000",
#     "physical_address": "4001 W NEWBERRY RD, STE A-1",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "4001 W NEWBERRY RD, STE A-1",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32607",
#     "business_phone": "352-337-8373",
#     "email": "JOSHUA@LAWGAINESVILLE.COM",
#     "owner": "SILVERMAN & MACK, LLC",
#     "latitude": "29.65374298900008",
#     "longitude": "-82.38501425199996",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.38501425199996,
#         29.65374298900008
#       ]
#     },
#     ":@computed_region_axii_i744": "3",
#     ":@computed_region_ecgy_hwrz": "7",
#     ":@computed_region_e6r8_dw75": "33",
#     ":@computed_region_u9vc_vmbc": "6",
#     ":@computed_region_4rat_gsiv": "768",
#     ":@computed_region_43jd_v64e": "4",
#     ":@computed_region_ndi2_bfht": "6"
#   },
#   {
#     "business_type": "BARBER SHOP",
#     "id": "34983",
#     "name": "BJW ENTERPRISES II LLC",
#     "start_date": "2007-09-29T00:00:00.000",
#     "physical_address": "15 W UNIVERSITY AVE",
#     "physical_city": "GAINESVILLE",
#     "physical_state": "FL",
#     "mailing_address": "15 W UNIVERSITY AVE",
#     "mailing_city": "GAINESVILLE",
#     "mailing_state": "FL",
#     "mailing_zip_code": "32601",
#     "business_phone": "352-373-4841",
#     "email": "BJWSR39@AIM.COM",
#     "owner": "BJW ENTERPRISES II LLC",
#     "latitude": "29.651978",
#     "longitude": "-82.325141",
#     "location": {
#       "type": "Point",
#       "coordinates": [
#         -82.325141,
#         29.651978
#       ]
#     },
#     ":@computed_region_axii_i744": "1",
#     ":@computed_region_ecgy_hwrz": "1",
#     ":@computed_region_e6r8_dw75": "13",
#     ":@computed_region_u9vc_vmbc": "1",
#     ":@computed_region_4rat_gsiv": "772",
#     ":@computed_region_9cfm_spy5": "2",
#     ":@computed_region_43jd_v64e": "14",
#     ":@computed_region_ndi2_bfht": "1"
#   }
# ]

# %%
arcpy.TruncateTable_management(tbl)
# Out:
# <Result 'C:\\Users\\friendde\\Documents\\ArcGIS\\Projects\\MIMS\\MIMS.gdb\\BusinessCity'>

# %%
# use try/except to catch keyerror
for item in data:
    try:
        cursor = arcpy.da.InsertCursor(tbl,flds)
        bizowner = item['owner']
        bizname = item['name']
        bizphone = item['business_phone']
        biztype = item['business_type']
        bizaddress = item['location_address']
        location = getCoords(item['location'])
        locationX = location[0]
        locationY = location[1]
        tupleXY = (locationX,locationY)
        #print(bizname,'\n','\t',bizphone,'\n','\t',biztype,'\n','\t',bizaddress,'\n','\t',locationX,locationY)
        #business = [bizname,bizphone,biztype,bizaddress,bizowner,locationX,locationY,tupleXY]
        business = [bizname,bizphone,biztype,bizaddress,bizowner,locationX,locationY]
        print(business)
        cursor.insertRow(business)
        del cursor
    except KeyError:
        location = [0,0]
        tupleXY = (0,0)
        continue

# %% [markdown]
# ### Use numpy and pandas to export to CSV
#
# Use arcpy [```TableToNumPyArray()```](http://pro.arcgis.com/en/pro-app/arcpy/data-access/tabletonumpyarray.htm)
# See also [Working with numpy in ArcGIS](http://pro.arcgis.com/en/pro-app/arcpy/get-started/working-with-numpy-in-arcgis.htm)

# %% [markdown]
# #nparr = arcpy.da.TableToNumPyArray(tbl,flds,skip_nulls=True)
# #pdarr = pd.DataFrame(nparr)
# #pdarr.to_csv(custAcctFile,header=False, index=False)

# %% [markdown]
# Ready new numpy array for consumption analysis

# %%
nparr = arcpy.da.TableToNumPyArray(tbl,flds,skip_nulls=True)
df = pd.DataFrame(nparr)
df.head(10)
# Out:
# Empty DataFrame
# Columns: [BusinessName, BusinessPhone, BusinessType, BusinessAddress, BusinessOwner, POINT_X, POINT_Y]
# Index: []

# %%
df.groupby('BusinessType')['BusinessType'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-945b94ba065e> in <module>
# ----> 1 df.groupby('BusinessType')['BusinessType'].value_counts()
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\groupby\generic.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    1137
#    1138         # multi-index components
# -> 1139         labels = list(map(rep, self.grouper.recons_labels)) + [llab(lab, inc)]
#    1140         levels = [ping.group_index for ping in self.grouper.groupings] + [lev]
#    1141         names = self.grouper.names + [self._selection_name]
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\groupby\generic.py in <lambda>(lab, inc)
#    1107         if bins is None:
#    1108             lab, lev = algorithms.factorize(val, sort=True)
# -> 1109             llab = lambda lab, inc: lab[inc]
#    1110         else:
#    1111
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 0 but corresponding boolean dimension is 1

# %% [markdown]
# #pivot table
# pivotTbl = df.pivot_table(values=["BusinessType"], index=["BusinessType"], aggfunc='count')
# pivotTbl

# %% [markdown]
# [```gis.features.SpatialDataFrame()```](https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.features.toc.html?highlight=spatialdataframe#arcgis.features.SpatialDataFrame.from_xy)

# %%
from arcgis.features import SpatialDataFrame
from arcgis.gis import GIS
from getpass import getpass
from IPython.display import display

# %%
sdf = SpatialDataFrame.from_xy(df,"POINT_X","POINT_Y")
display(sdf)

# %%
#gis = GIS("https://wms.gru.com/portal", username=input("Enter User Name "), password=(getpass()))
gis = GIS(arcpy.GetActivePortalURL(), username=input("Enter User Name "), password=(getpass()))
#gis = GIS()
#portalDesc = arcpy.GetPortalDescription()
# search and list all items owned by connected user
#query=f'owner:{portalDesc["user"]["username"]} AND title:CW BaseMap'
#itemType="Feature Layer"
#sortField="title"
#sortOrder="asc"
# default max__items is 10
#maxItems=100
#m = gis.content.search(query,itemType,sortField,sortOrder,maxItems)

# %%
bizLayer = gis.content.import_data(sdf)

# %%
m = gis.map('Gainesville,FL')

# %%
m

# %%
m.add_layer(bizLayer)
m
